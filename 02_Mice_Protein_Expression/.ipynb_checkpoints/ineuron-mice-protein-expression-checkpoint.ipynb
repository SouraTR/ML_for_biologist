# %% [markdown]
# # Mice Protein Expression Dataset
# The data set includes the expression levels of 77 proteins/protein changes that generated
# measurable signals in the cortex's nuclear fraction. There are 72 mice in all, with 38
# control mice and 34 trisomic mice (Down syndrome). In the experiments, 15
# measurements of each protein per sample/mouse were recorded. As a result, there are
# **38x15**, or 570 measurements for control mice and **34x15**, or 510 measurements for
# trisomic mice. There are 1080 measurements per protein in the dataset. Each
# measurement can be thought of as a separate sample/mouse.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_orig = pd.read_csv("./Data_Cortex_Nuclear.csv")
df = df_orig.copy()

# %%
df_orig.shape
# Out:
# (1080, 82)

# %% [markdown]
# ## Original Data
#
# - Number of samples = 1080
# - Number of proteins = 77

# %%
df.head()
# Out:
#   MouseID  DYRK1A_N   ITSN1_N    BDNF_N     NR1_N    NR2A_N    pAKT_N  \
# 0   309_1  0.503644  0.747193  0.430175  2.816329  5.990152  0.218830
# 1   309_2  0.514617  0.689064  0.411770  2.789514  5.685038  0.211636
# 2   309_3  0.509183  0.730247  0.418309  2.687201  5.622059  0.209011
# 3   309_4  0.442107  0.617076  0.358626  2.466947  4.979503  0.222886
# 4   309_5  0.434940  0.617430  0.358802  2.365785  4.718679  0.213106
#
#     pBRAF_N  pCAMKII_N   pCREB_N  ...   pCFOS_N     SYP_N  H3AcK18_N  \
# 0  0.177565   2.373744  0.232224  ...  0.108336  0.427099   0.114783
# 1  0.172817   2.292150  0.226972  ...  0.104315  0.441581   0.111974
# 2  0.175722   2.283337  0.230247  ...  0.106219  0.435777   0.111883
# 3  0.176463   2.152301  0.207004  ...  0.111262  0.391691   0.130405
# 4  0.173627   2.134014  0.192158  ...  0.110694  0.434154   0.118481
#
#      EGR1_N  H3MeK4_N    CaNA_N  Genotype  Treatment  Behavior   class
# 0  0.131790  0.128186  1.675652   Control  Memantine       C/S  c-CS-m
# 1  0.135103  0.131119  1.743610   Control  Memantine       C/S  c-CS-m
# 2  0.133362  0.127431  1.926427   Control  Memantine       C/S  c-CS-m
# 3  0.147444  0.146901  1.700563   Control  Memantine       C/S  c-CS-m
# 4  0.140314  0.148380  1.839730   Control  Memantine       C/S  c-CS-m
#
# [5 rows x 82 columns]

# %%
df.loc[:, "class"].value_counts()
# Out:
# c-CS-m    150
# c-SC-m    150
# c-CS-s    135
# c-SC-s    135
# t-CS-m    135
# t-SC-m    135
# t-SC-s    135
# t-CS-s    105
# Name: class, dtype: int64

# %% [markdown]
# ## Extraction of matrix

# %%
matrix = df.iloc[:, 1:-4]
matrix.head()
# Out:
#    DYRK1A_N   ITSN1_N    BDNF_N     NR1_N    NR2A_N    pAKT_N   pBRAF_N  \
# 0  0.503644  0.747193  0.430175  2.816329  5.990152  0.218830  0.177565
# 1  0.514617  0.689064  0.411770  2.789514  5.685038  0.211636  0.172817
# 2  0.509183  0.730247  0.418309  2.687201  5.622059  0.209011  0.175722
# 3  0.442107  0.617076  0.358626  2.466947  4.979503  0.222886  0.176463
# 4  0.434940  0.617430  0.358802  2.365785  4.718679  0.213106  0.173627
#
#    pCAMKII_N   pCREB_N    pELK_N  ...     SHH_N     BAD_N  BCL2_N     pS6_N  \
# 0   2.373744  0.232224  1.750936  ...  0.188852  0.122652     NaN  0.106305
# 1   2.292150  0.226972  1.596377  ...  0.200404  0.116682     NaN  0.106592
# 2   2.283337  0.230247  1.561316  ...  0.193685  0.118508     NaN  0.108303
# 3   2.152301  0.207004  1.595086  ...  0.192112  0.132781     NaN  0.103184
# 4   2.134014  0.192158  1.504230  ...  0.205604  0.129954     NaN  0.104784
#
#     pCFOS_N     SYP_N  H3AcK18_N    EGR1_N  H3MeK4_N    CaNA_N
# 0  0.108336  0.427099   0.114783  0.131790  0.128186  1.675652
# 1  0.104315  0.441581   0.111974  0.135103  0.131119  1.743610
# 2  0.106219  0.435777   0.111883  0.133362  0.127431  1.926427
# 3  0.111262  0.391691   0.130405  0.147444  0.146901  1.700563
# 4  0.110694  0.434154   0.118481  0.140314  0.148380  1.839730
#
# [5 rows x 77 columns]

# %%
missing_values = pd.DataFrame({"sample": matrix.index, "Number of missing values": matrix.T.isna().sum()})
missing_values.to_csv("missing_values.csv", index=False)

# %% [markdown]
# ## Dealing with missing values - Sample level
#
# Sample number 987, 988, 989 have 43 missing protein measurements
# We will remove these

# %%
df.loc[987:989]
# Out:
#      MouseID  DYRK1A_N  ITSN1_N  BDNF_N  NR1_N  NR2A_N  pAKT_N  pBRAF_N  \
# 987  3426_13       NaN      NaN     NaN    NaN     NaN     NaN      NaN
# 988  3426_14       NaN      NaN     NaN    NaN     NaN     NaN      NaN
# 989  3426_15       NaN      NaN     NaN    NaN     NaN     NaN      NaN
#
#      pCAMKII_N  pCREB_N  ...   pCFOS_N     SYP_N  H3AcK18_N    EGR1_N  \
# 987        NaN      NaN  ...  0.112854  0.405540   0.151693  0.163125
# 988        NaN      NaN  ...  0.120664  0.422986   0.175044  0.185038
# 989        NaN      NaN  ...  0.098278  0.427405   0.172209  0.200861
#
#      H3MeK4_N    CaNA_N  Genotype  Treatment  Behavior   class
# 987  0.208852  1.443353    Ts65Dn     Saline       S/C  t-SC-s
# 988  0.195326  1.443269    Ts65Dn     Saline       S/C  t-SC-s
# 989  0.233076  1.495249    Ts65Dn     Saline       S/C  t-SC-s
#
# [3 rows x 82 columns]

# %%
df.drop([987, 988, 989], axis=0, inplace=True)

# %% [markdown]
# ## Dealing with missing values: Protein level

# %%
missing_values_proteins = pd.DataFrame({"protein": matrix.T.index, "Number of samples protein missing from": matrix.isna().sum()})
missing_values_proteins.to_csv("missing_values_proteins.csv", index=False)

# %% [markdown]
# Removing these proteins because they are missing from too many samples
#
# * BAD_N	213
# * BCL2_N	285
# * pCFOS_N	75
# * H3AcK18_N	180
# * EGR1_N	210
# * H3MeK4_N	270

# %%
df.drop(["BAD_N", "BCL2_N", "pCFOS_N", "H3AcK18_N", "EGR1_N", "H3MeK4_N"], axis=1, inplace=True)

# %% [markdown]
# ## Extract the matrix for quality check plottings

# %%
matrix = df.iloc[:, 1:-4]
print(matrix.shape)
matrix.head()
# Out:
# (1077, 71)
#    DYRK1A_N   ITSN1_N    BDNF_N     NR1_N    NR2A_N    pAKT_N   pBRAF_N  \
# 0  0.503644  0.747193  0.430175  2.816329  5.990152  0.218830  0.177565
# 1  0.514617  0.689064  0.411770  2.789514  5.685038  0.211636  0.172817
# 2  0.509183  0.730247  0.418309  2.687201  5.622059  0.209011  0.175722
# 3  0.442107  0.617076  0.358626  2.466947  4.979503  0.222886  0.176463
# 4  0.434940  0.617430  0.358802  2.365785  4.718679  0.213106  0.173627
#
#    pCAMKII_N   pCREB_N    pELK_N  ...   P3525_N  pCASP9_N   PSD95_N    SNCA_N  \
# 0   2.373744  0.232224  1.750936  ...  0.247538  1.603310  2.014875  0.108234
# 1   2.292150  0.226972  1.596377  ...  0.257632  1.671738  2.004605  0.109749
# 2   2.283337  0.230247  1.561316  ...  0.255343  1.663550  2.016831  0.108196
# 3   2.152301  0.207004  1.595086  ...  0.251103  1.484624  1.957233  0.119883
# 4   2.134014  0.192158  1.504230  ...  0.251773  1.534835  2.009109  0.119524
#
#    Ubiquitin_N  pGSK3B_Tyr216_N     SHH_N     pS6_N     SYP_N    CaNA_N
# 0     1.044979         0.831557  0.188852  0.106305  0.427099  1.675652
# 1     1.009883         0.849270  0.200404  0.106592  0.441581  1.743610
# 2     0.996848         0.846709  0.193685  0.108303  0.435777  1.926427
# 3     0.990225         0.833277  0.192112  0.103184  0.391691  1.700563
# 4     0.997775         0.878668  0.205604  0.104784  0.434154  1.839730
#
# [5 rows x 71 columns]

# %% [markdown]
# ## Impute missing values
#
# We will impute missing values with average expression level of protein across all the samples
#
# - There are better ways to do this by using regression imputation
# - We want to do it quickly since this part is not the focus of this exercise

# %%
for i in matrix.columns:
    matrix[i].fillna(matrix[i].mean(), inplace=True)

# %%
# div = matrix.mean(axis=1)
# matrix2 = matrix.apply(lambda x: x/div, axis=0)
# matrix2.head()

# %%
matrix_log = matrix.apply(np.log)

# %%
plt.figure(figsize=(25, 10))
plt.boxplot(matrix.T, showcaps=False, meanline=False, showbox=False, showfliers=False)
plt.tick_params(labelbottom = False)
plt.xlabel("Samples")
plt.show()

# %%
plt.figure(figsize=(25, 10))
plt.boxplot(matrix_log.T, showcaps=False, meanline=False, showbox=False, showfliers=False)
plt.tick_params(labelbottom = False)
plt.xlabel("Samples")
plt.show()

# %%
matrix_log.shape
# Out:
# (1077, 71)

# %% [markdown]
# ## Our data is cleaned
#
# - Number of proteins = 71 (from 77)
# - Number of samples = 1077 (from 1080)
#
# **Log transformed the data**

# %% [markdown]
# ## Correlation Plot
#
# We can see correlation in the data

# %%
mask = np.triu(matrix_log.corr())
plt.figure(figsize=(20,20))
corr = matrix_log.corr()
sns.heatmap(corr, linewidths=0.2, mask=mask, cmap=plt.cm.CMRmap_r)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Collinearity in the data
#
# We want to remove multiple collinearity from the data before creating a model
#
# Two proteins having the same outcome will cause biasness in our model

# %%
def corrRemove(data_matrix = None, threshold_val = None):
    correlation_matrix = data_matrix.corr()
    outDict = dict()
    for col_name in correlation_matrix.columns:
        vals = None
        vals = list(correlation_matrix.loc[:, col_name][correlation_matrix.loc[:, col_name] > threshold_val].index)
        vals.remove(col_name)
        if len(vals) > 0:
            outDict[col_name] = vals
    return outDict

# %%
corrRemove(matrix_log, 0.9)
# Out:
# {'DYRK1A_N': ['ITSN1_N', 'pERK_N', 'BRAF_N'],
#  'ITSN1_N': ['DYRK1A_N'],
#  'NR1_N': ['pNR1_N', 'Bcatenin_N'],
#  'pERK_N': ['DYRK1A_N'],
#  'pNR1_N': ['NR1_N'],
#  'BRAF_N': ['DYRK1A_N'],
#  'Bcatenin_N': ['NR1_N'],
#  'ARC_N': ['pS6_N'],
#  'pS6_N': ['ARC_N']}

# %% [markdown]
# ## Collinearity
#
# The first protein crosses the threshold of `Pearson's R = 0.9 ` with multiple proteins
#
# Removing `DYRK1A_N` `NR1_N` `ARC_N`

# %%
matrix_collinearity = matrix_log.drop(["DYRK1A_N", "NR1_N", "ARC_N"], axis=1)

# %%
corrRemove(matrix_collinearity, 0.9)
# Out:
# {}

# %% [markdown]
# No high collinearity in the data anymore

# %%
matrix_collinearity.isnull().sum()[matrix_collinearity.isnull().sum() > 0]
# Out:
# RRP1_N    1
# dtype: int64

# %%
matrix_collinearity_copy = matrix_collinearity.copy()
matrix_collinearity_copy.isnull().sum()[matrix_collinearity_copy.isnull().sum() > 0]
# Out:
# RRP1_N    1
# dtype: int64

# %%
matrix_collinearity_copy.T.isnull().sum()[matrix_collinearity_copy.T.isnull().sum() > 0]
# Out:
# 298    1
# dtype: int64

# %%
matrix_collinearity_copy.loc[298, "RRP1_N"] = matrix_collinearity_copy.loc[:, "RRP1_N"].mean()

# %% [markdown]
# ## Plotting the data
#
# We will create a PCA to check if out features have any inherent variation
#
# - Create PCA
# - Color by target variable

# %% [markdown]
# ## EDA
#
# I would like to see if the proteins are clustering
#
# The number of clusters would give me an idea if we can use the protein levels to predict something
#
# For clustering the go to choice is PCA, if I find the PCA to be in proper shape, I can try to implement (O)PLS-DA to find out the most discriminating proteins between the control and treated conditions

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
df.head()
# Out:
#   MouseID  DYRK1A_N   ITSN1_N    BDNF_N     NR1_N    NR2A_N    pAKT_N  \
# 0   309_1  0.503644  0.747193  0.430175  2.816329  5.990152  0.218830
# 1   309_2  0.514617  0.689064  0.411770  2.789514  5.685038  0.211636
# 2   309_3  0.509183  0.730247  0.418309  2.687201  5.622059  0.209011
# 3   309_4  0.442107  0.617076  0.358626  2.466947  4.979503  0.222886
# 4   309_5  0.434940  0.617430  0.358802  2.365785  4.718679  0.213106
#
#     pBRAF_N  pCAMKII_N   pCREB_N  ...  Ubiquitin_N  pGSK3B_Tyr216_N     SHH_N  \
# 0  0.177565   2.373744  0.232224  ...     1.044979         0.831557  0.188852
# 1  0.172817   2.292150  0.226972  ...     1.009883         0.849270  0.200404
# 2  0.175722   2.283337  0.230247  ...     0.996848         0.846709  0.193685
# 3  0.176463   2.152301  0.207004  ...     0.990225         0.833277  0.192112
# 4  0.173627   2.134014  0.192158  ...     0.997775         0.878668  0.205604
#
#       pS6_N     SYP_N    CaNA_N  Genotype  Treatment  Behavior   class
# 0  0.106305  0.427099  1.675652   Control  Memantine       C/S  c-CS-m
# 1  0.106592  0.441581  1.743610   Control  Memantine       C/S  c-CS-m
# 2  0.108303  0.435777  1.926427   Control  Memantine       C/S  c-CS-m
# 3  0.103184  0.391691  1.700563   Control  Memantine       C/S  c-CS-m
# 4  0.104784  0.434154  1.839730   Control  Memantine       C/S  c-CS-m
#
# [5 rows x 76 columns]

# %%
# y variable
df.loc[:, "Behavior"].unique()
# Out:
# array(['C/S', 'S/C'], dtype=object)

# %%
X = matrix_collinearity_copy.copy()
y = df.loc[:, "Behavior"]

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
pca = PCA(.80)
pca.fit(X_scaled)
# Out:
# PCA(n_components=0.8)

# %%
PC_values = np.arange(pca.n_components_) + 1
plt.figure(figsize=(12, 8))
# plt.plot(PC_values, pca.explained_variance_ratio_, 'o-', linewidth=2, color='blue')
plt.bar(PC_values, pca.explained_variance_ratio_)#, 'o-', linewidth=2, color='blue')
plt.plot(PC_values, np.cumsum(pca.explained_variance_ratio_), 'o-', linewidth=2, color='orange')
plt.title('Scree Plot')
plt.xlabel('Principal Component')
plt.ylabel('Variance Explained')
plt.show()

# %%
pca = PCA(2)
projected = pca.fit_transform(X_scaled)
print(X_scaled.shape)
print(projected.shape)
# Out:
# (1077, 68)
# (1077, 2)

# %%
import plotly.express as px

# %%
plotly_data = {"PC1": projected[:, 0], "PC2": projected[:, 1]}

# %%
fig = px.scatter(plotly_data, x="PC1", y="PC2", color=y)
fig.show()
# Out:
# <div>                            <div id="6c608dd7-e073-4476-92ff-276bbd73341f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6c608dd7-e073-4476-92ff-276bbd73341f")) {                    Plotly.newPlot(                        "6c608dd7-e073-4476-92ff-276bbd73341f",                        [{"hovertemplate":"color=C/S<br>PC1=%{x}<br>PC2=%{y}<extra></extra>","legendgroup":"C/S","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"C/S","showlegend":true,"x":[-4.127017913834349,-2.69361318042095,-2.8363507739371325,-0.8487365900393683,0.13130770516763615,0.20639849626714452,0.48118463476276746,1.870350707528282,3.6120712954798146,1.7301951892053182,2.3691332800979077,2.9403382212863045,3.6124549623642257,3.683659896819077,4.862857357126218,-4.711004850913573,-1.671130674433657,-1.5294209159172432,-3.242164769591001,1.9899322365457603,0.27620791861890925,-3.0531787493953755,-1.5992351597281094,1.7965277375642539,-0.2700042115108048,-4.404041693840365,1.3653337494591802,3.576743502770792,2.570456122930063,3.7970246550920796,-7.5222439191184955,-8.582828494895045,-8.99957219386195,-5.453790450100156,-6.920472715207169,-7.853271625859142,-3.865585363014292,-5.307767192778413,-6.75011268432332,-5.576209952526369,-6.214255786257338,-6.886695331448479,-4.393946807421618,-5.550488075458789,-6.075378967154587,-5.998791920930949,-6.2853791789462115,-7.2456154914382385,-5.480587300879159,-5.967216393397465,-6.664299964653036,-3.212871528996343,-5.112163290550456,-5.926261103384989,-2.6249211229541483,-3.04642439310764,-2.721202993850565,-2.4065799138801585,-2.8916051202871054,-2.8202056211485274,-0.5703370664569222,-2.039791134349673,-2.5071231827490212,-1.1331766540238373,-1.3073280301648644,-1.989095336805463,0.05016537740740434,-0.6325907652912316,-0.1743680045904039,0.26986924735959317,0.636338024328992,-0.23316046851317693,-0.32206631462486257,-1.4615610638298633,-1.0728069645984406,-5.270564026545946,-4.885450887149223,-5.84829238608017,-1.99095280838442,-2.4366830033273996,-2.4586519094794337,0.9066090890460015,1.6645487917633677,0.2837282943238498,4.277698336727297,3.3201709170599374,2.9534102884785334,9.727949523559824,9.09109397616733,8.423491862029284,-1.7414838277809475,-2.374144966057373,-2.1913174160971347,2.2481972299881674,2.1175852376549154,1.873842324056278,6.439280590970519,6.138839858265495,4.425701366306064,7.907274926807842,7.593580777923896,6.164456063419142,10.023108334538707,10.038634651798109,10.083167343522048,-1.878623046187763,-1.4636758067941187,-2.165127617773057,0.8054465936996311,0.3211176976789146,-0.6493363329150258,1.5665891499652898,-0.21230713642826055,-0.37876882117151756,3.1494050761113517,1.725030345301183,0.08175532512785984,-0.277434445234826,1.26255000488898,0.6265889449573364,-5.499201245319091,-6.2168186279944315,-6.4032760853207975,-4.32114377738832,-3.6801996662893575,-4.413463147006432,-2.0456471652487247,-1.4902328444102904,-0.9386695385315932,0.29193005522438714,-0.7750375568914706,0.24707779430634594,-0.09044977029181221,-1.526671948102124,0.4224442986499688,-5.762663088708302,-6.026591588974966,-5.143004423812803,-3.976913618724894,-3.7316878103234483,-3.2649375770479203,-1.5149878454815393,-1.2289965054765388,-0.8359804530129281,-0.402281021053017,-0.8899920247301535,-1.3866196789561784,1.1280455656483215,0.4586421503063677,1.6369364334027636,-5.769976514785399,-7.2841925342527745,-8.076117911560226,-4.461881436462286,-4.7285005523312,-6.631812169505931,-1.7522557397159542,-3.2056766287089693,-5.454890000691382,-2.9267805068503083,-3.6650861482057366,-4.8365178357923035,-1.7410554486620335,-3.0634590963868087,-3.333401606215305,-5.596874857567444,-6.956478445979938,-8.36765256557993,-3.069791123010235,-3.8393980982295983,-4.8333063890 ...

# %% [markdown]
# ## Good News
#
# We see a distinct separation of our classes with a unsupervised technique PCA

# %% [markdown]
# ## Comparision with data without any processing
#
# We want to see if out feature selection and transformation is having any effect on the PCA

# %%
df.shape
# Out:
# (1077, 76)

# %%
df.head(1)
# Out:
#   MouseID  DYRK1A_N   ITSN1_N    BDNF_N     NR1_N    NR2A_N   pAKT_N  \
# 0   309_1  0.503644  0.747193  0.430175  2.816329  5.990152  0.21883
#
#     pBRAF_N  pCAMKII_N   pCREB_N  ...  Ubiquitin_N  pGSK3B_Tyr216_N     SHH_N  \
# 0  0.177565   2.373744  0.232224  ...     1.044979         0.831557  0.188852
#
#       pS6_N     SYP_N    CaNA_N  Genotype  Treatment  Behavior   class
# 0  0.106305  0.427099  1.675652   Control  Memantine       C/S  c-CS-m
#
# [1 rows x 76 columns]

# %%
XX = df.iloc[:, 1:-4]
yy = df.loc[:, 'Behavior']

# %%
for i in XX.columns:
    XX[i].fillna(XX[i].mean(), inplace=True)

# %%
pca_XX = PCA(2)
projected_XX = pca_XX.fit_transform(XX)
print(XX.shape)
print(projected_XX.shape)
# Out:
# (1077, 71)
# (1077, 2)

# %%
plotly_data__XX = {"PC1": projected_XX[:, 0], "PC2": projected_XX[:, 1]}

# %% [markdown]
# ## Difference between the PCA plots are there
#
# Not as much as I wished there to be

# %%
fig = px.scatter(plotly_data, x="PC1", y="PC2", color=yy)
fig.show()
# Out:
# <div>                            <div id="7c232c06-1b7f-4b1d-8cc0-f5ab2d92d749" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7c232c06-1b7f-4b1d-8cc0-f5ab2d92d749")) {                    Plotly.newPlot(                        "7c232c06-1b7f-4b1d-8cc0-f5ab2d92d749",                        [{"hovertemplate":"color=C/S<br>PC1=%{x}<br>PC2=%{y}<extra></extra>","legendgroup":"C/S","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"C/S","showlegend":true,"x":[1.3348254691744021,0.920579313520743,0.8917127365079113,0.017430895308559728,-0.2205333159196525,-0.17357685514004534,-0.6143230248777941,-0.8049625697163285,-1.1697552493458494,-1.6553175145403463,-1.6456963729222143,-1.854878820596811,-2.1268343481509846,-2.136823770985751,-2.310176515841457,1.222638153737978,0.509392932737711,0.45271989956179925,0.22850589011704142,-0.8573682309676147,-0.4567549577871097,-0.37204969759416295,-0.6804901387467428,-1.129608784708408,-1.5318413151868633,-0.7204937450721599,-1.8160685399459642,-2.5908708102111953,-2.4549688626271093,-2.6298207203360504,1.3263199794300953,1.5751630137580197,1.6072101694135488,1.1123586567193504,1.4244352420097937,1.7909461376539748,0.5050827753215905,0.9009363601330401,1.3515919292154945,0.5717950844541961,0.7402995098163985,1.063207700540849,0.03379268462479316,0.19498245132830108,0.40972788226920076,1.4683301263689938,1.464053983502957,1.7772774521104844,1.4157300353191442,1.5683617096472422,1.7586003001616697,0.6823931730410547,0.9619725757186418,1.227050316308614,-0.18164307517115966,-0.1608273318980286,-0.09586093148638644,-0.521218008190973,-0.42879487281966594,-0.44117609562705296,0.7242849927419857,1.140441993256648,1.2489342549350986,0.8325070982066574,0.7019356753118513,0.9487317075694206,-0.007178142722871556,0.030225871810720548,0.08487185724944898,-0.5687742069847573,-0.6185604501708354,-0.4289570655080689,-0.8338967859438419,-0.7070828856868452,-0.7583938374575847,1.8425303715706558,1.7782782206623537,2.0184020544593544,1.150780138127313,1.270982447698308,1.2090452515045316,0.446656962416689,0.2096956841347556,0.5925017996102472,-0.985149115877059,-0.9660070341095507,-0.807895247639241,-1.9443773539735014,-1.9506686919692566,-1.9249972937890025,0.7958151564449614,0.9835946216133682,1.0821273104688343,0.007881064218469614,0.1707783052643015,0.1948210424821563,-1.0764967457317907,-1.119988893846287,-0.7160966025387053,-1.6959242769569525,-1.6573287011689277,-1.4464410143061432,-2.40220659861457,-2.380616763134249,-2.4212171237865947,0.4421102423229865,0.3907646897656915,0.6242099689056728,-0.49440223744831746,-0.30518273007555125,-0.12470475069075085,-0.9538949444826813,-0.5390288588903891,-0.6229525921056264,-1.9272444791911614,-1.8290280613543042,-1.3507333485295272,-1.9692487789922821,-2.1852971834175787,-2.0473127118520766,1.7764226488011983,1.7439412750172683,1.83676386906944,1.2780904775888464,0.935588825217407,1.0408677925210752,0.3948261752889088,0.23880733996972553,-0.031682963545440035,-0.6386506185277061,-0.4671453031285199,-0.7388978623556671,-1.0027703124874743,-0.7874168884928474,-1.0719233314039684,1.732959694069123,1.93362366481103,1.5070416823637034,2.0015187296714503,2.1036812755682774,1.8520482812448449,1.3879224042686191,1.3945714194711893,1.4907390871251616,0.7831708382837134,0.9110758138754063,0.9213628364397431,0.3279207453284741,0.322779373625424,-0.05482439673035988,2.209486936832667,2.5911617402140354,2.9254588802107437,1.9179673520762257,1.9764172501228086,2.72600953314514,0.7773518202379351,1.0821356195994798,1.7793290786645644,0.3013014016720999,0.5210916252697032,0.8621787831024381,-0.2517291990063801,0.0007955441447183467,0.014976893432682744,1.9039403572111075,2.142936144485303,2.5391193690392786,0.7773115286828685 ...

# %% [markdown]
# ## Missing Values
#
# Missing values in columns

# %%
p = (df.columns, df.isnull().sum(axis=0))
# list(filter(lambda x: x[1]>0 ,list(zip(*p))))
pd.DataFrame(p).T

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, RidgeCV
df_dropna = df.copy()
df_dropna.set_index(["MouseID", "Genotype"], inplace=True, drop=True)

df_dropna = df_dropna.dropna(how = "all")
df_dropna = df_dropna.dropna(thresh=72)

print(df_dropna.shape)
df_dropna.head()

# %%
df_dropna.isna().sum()

# %%
missing_columns = df_dropna.columns[df_dropna.isna().sum() != 0]
missing_columns

# %% [markdown]
# ## Imputation
#
# Using LinearRegression model to impute the missing data
#
# We create a subset of missing data and use the non missing columns to predict their values with the help of a regression model, the scores of the predictions as we can see are pretty good (>0.8)

# %%
# creating subset of missing data and applying regression imoutation
deter_data = pd.DataFrame(columns = ["Det_" + name for name in missing_columns])

for feature in missing_columns:
    deter_data.loc[:, "Det_" + feature] = df_dropna.loc[:, feature]
    parameters = list(set(df_dropna.columns) - set(missing_columns) - {feature})
    
    #Create a Linear Regression model to estimate the missing data
    model = LinearRegression()
    dfIntermin = pd.concat([df_dropna[parameters], df_dropna[feature]], axis=1).dropna()
    
    X_train, X_test, y_train, y_test = train_test_split(dfIntermin.loc[:, parameters], dfIntermin.loc[:, feature],
                                                        test_size=0.2, random_state=42)
    
    model.fit(X = X_train, y = y_train)
    print(model.score(X_test, y_test))
    
    #observe that I preserve the index of the missing data from the original dataframe
    deter_data.loc[df_dropna[feature].isnull(), "Det_" + feature] = model.predict(df_dropna[parameters])[df_dropna[feature].isnull()]

# %%
# creating subset of missing data and applying regression imoutation
deter_data = pd.DataFrame(columns = [name for name in missing_columns])

for feature in missing_columns:
    deter_data.loc[:, feature] = df_dropna.loc[:, feature]
    parameters = list(set(df_dropna.columns) - set(missing_columns) - {feature})
    
    #Create a Linear Regression model to estimate the missing data
    model = LinearRegression()
    dfIntermin = pd.concat([df_dropna[parameters], df_dropna[feature]], axis=1).dropna()
    
    X_train, X_test, y_train, y_test = train_test_split(dfIntermin.loc[:, parameters], dfIntermin.loc[:, feature],
                                                        test_size=0.2, random_state=42)
    
    model.fit(X = X_train, y = y_train)
    print(model.score(X_test, y_test))
    
    #observe that I preserve the index of the missing data from the original dataframe
    deter_data.loc[df_dropna[feature].isnull(), feature] = model.predict(df_dropna[parameters])[df_dropna[feature].isnull()]
    
deter_data

# %%
df_filled = df_dropna.fillna(deter_data)
df_filled.isna().sum()

# %%
df_filled.shape
